# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread('home.png')
gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
img=cv.drawKeypoints(gray,kp,img)
cv.imwrite('sift_keypoints.jpg',img)
# Out:
# True

# %%
img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv.imwrite('sift_keypoints1.jpg',img)
# Out:
# True

# %%
sift = cv.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

# %%
kp, des
# Out:
# ((< cv2.KeyPoint 00000249506207E0>,
#   < cv2.KeyPoint 0000024950623DE0>,
#   < cv2.KeyPoint 000002495033E160>,
#   < cv2.KeyPoint 000002495033E700>,
#   < cv2.KeyPoint 000002495033DFE0>,
#   < cv2.KeyPoint 000002495033E460>,
#   < cv2.KeyPoint 0000024950635F20>,
#   < cv2.KeyPoint 0000024950635FE0>,
#   < cv2.KeyPoint 00000249506345A0>,
#   < cv2.KeyPoint 0000024950635B00>,
#   < cv2.KeyPoint 0000024950635E60>,
#   < cv2.KeyPoint 0000024950635D70>,
#   < cv2.KeyPoint 0000024950636010>,
#   < cv2.KeyPoint 0000024950635E90>,
#   < cv2.KeyPoint 00000249506361F0>,
#   < cv2.KeyPoint 0000024950636190>,
#   < cv2.KeyPoint 00000249506360A0>,
#   < cv2.KeyPoint 0000024950636220>,
#   < cv2.KeyPoint 0000024950636460>,
#   < cv2.KeyPoint 0000024950636280>,
#   < cv2.KeyPoint 0000024950636100>,
#   < cv2.KeyPoint 0000024950635FB0>,
#   < cv2.KeyPoint 0000024950636370>,
#   < cv2.KeyPoint 0000024950636250>,
#   < cv2.KeyPoint 0000024950635B90>,
#   < cv2.KeyPoint 00000249506362B0>,
#   < cv2.KeyPoint 00000249506363A0>,
#   < cv2.KeyPoint 0000024950636340>,
#   < cv2.KeyPoint 00000249506361C0>,
#   < cv2.KeyPoint 0000024950636310>,
#   < cv2.KeyPoint 0000024950636430>,
#   < cv2.KeyPoint 00000249506363D0>,
#   < cv2.KeyPoint 0000024950636130>,
#   < cv2.KeyPoint 00000249506364C0>,
#   < cv2.KeyPoint 0000024950636520>,
#   < cv2.KeyPoint 00000249506356E0>,
#   < cv2.KeyPoint 00000249506364F0>,
#   < cv2.KeyPoint 00000249506365B0>,
#   < cv2.KeyPoint 0000024950636400>,
#   < cv2.KeyPoint 0000024950636790>,
#   < cv2.KeyPoint 0000024950636550>,
#   < cv2.KeyPoint 00000249506367C0>,
#   < cv2.KeyPoint 0000024950635B30>,
#   < cv2.KeyPoint 00000249506366A0>,
#   < cv2.KeyPoint 00000249506366D0>,
#   < cv2.KeyPoint 00000249506367F0>,
#   < cv2.KeyPoint 0000024950636820>,
#   < cv2.KeyPoint 0000024950636640>,
#   < cv2.KeyPoint 0000024950636730>,
#   < cv2.KeyPoint 00000249506365E0>,
#   < cv2.KeyPoint 0000024950636700>,
#   < cv2.KeyPoint 00000249506362E0>,
#   < cv2.KeyPoint 0000024950636910>,
#   < cv2.KeyPoint 00000249506369D0>,
#   < cv2.KeyPoint 0000024950636670>,
#   < cv2.KeyPoint 0000024950636940>,
#   < cv2.KeyPoint 0000024950635770>,
#   < cv2.KeyPoint 0000024950636850>,
#   < cv2.KeyPoint 0000024950636880>,
#   < cv2.KeyPoint 0000024950636A00>,
#   < cv2.KeyPoint 0000024950636AC0>,
#   < cv2.KeyPoint 0000024950636610>,
#   < cv2.KeyPoint 0000024950636BE0>,
#   < cv2.KeyPoint 0000024950636A30>,
#   < cv2.KeyPoint 0000024950636970>,
#   < cv2.KeyPoint 0000024950636A60>,
#   < cv2.KeyPoint 00000249506369A0>,
#   < cv2.KeyPoint 0000024950636B80>,
#   < cv2.KeyPoint 0000024950636D00>,
#   < cv2.KeyPoint 0000024950636D30>,
#   < cv2.KeyPoint 0000024950636BB0>,
#   < cv2.KeyPoint 0000024950636B20>,
#   < cv2.KeyPoint 0000024950636B50>,
#   < cv2.KeyPoint 0000024950636C40>,
#   < cv2.KeyPoint 0000024950636D60>,
#   < cv2.KeyPoint 0000024950635F50>,
#   < cv2.KeyPoint 0000024950636CD0>,
#   < cv2.KeyPoint 0000024950636C70>,
#   < cv2.KeyPoint 0000024950636490>,
#   < cv2.KeyPoint 0000024950636F40>,
#   < cv2.KeyPoint 0000024950636EE0>,
#   < cv2.KeyPoint 0000024950636AF0>,
#   < cv2.KeyPoint 0000024950636F10>,
#   < cv2.KeyPoint 0000024950636DF0>,
#   < cv2.KeyPoint 0000024950636D90>,
#   < cv2.KeyPoint 0000024950636E80>,
#   < cv2.KeyPoint 0000024950636E50>,
#   < cv2.KeyPoint 0000024950637060>,
#   < cv2.KeyPoint 00000249506368E0>,
#   < cv2.KeyPoint 0000024950637030>,
#   < cv2.KeyPoint 0000024950636EB0>,
#   < cv2.KeyPoint 0000024950637120>,
#   < cv2.KeyPoint 0000024950636FD0>,
#   < cv2.KeyPoint 0000024950636FA0>,
#   < cv2.KeyPoint 0000024950636E20>,
#   < cv2.KeyPoint 00000249506370F0>,
#   < cv2.KeyPoint 0000024950637150>,
#   < cv2.KeyPoint 0000024950637000>,
#   < cv2.KeyPoint 00000249506371B0>,
#   < cv2.KeyPoint 00000249506370C0>,
#   < cv2.KeyPoint 0000024950637180>,
#   < cv2.KeyPoint 0000024950636DC0>,
#   < cv2.KeyPoint 0000024950637090>,
#   < cv2.KeyPoint 0000024950637240>,
#   < cv2.KeyPoint 00000249506371E0>,
#   < cv2.KeyPoint 0000024950636580>,
#   < cv2.KeyPoint 0000024950637570>,
#   < cv2.KeyPoint 0000024950637450>,
#   < cv2.KeyPoint 00000249506374E0>,
#   < cv2.KeyPoint 00000249506373F0>,
#   < cv2.KeyPoint 00000249506372A0>,
#   < cv2.KeyPoint 0000024950637390>,
#   < cv2.KeyPoint 0000024950637630>,
#   < cv2.KeyPoint 0000024950637330>,
#   < cv2.KeyPoint 0000024950637360>,
#   < cv2.KeyPoint 00000249506375A0>,
#   < cv2.KeyPoint 0000024950636CA0>,
#   < cv2.KeyPoint 0000024950637720>,
#   < cv2.KeyPoint 0000024950637270>,
#   < cv2.KeyPoint 0000024950637510>,
#   < cv2.KeyPoint 00000249506374B0>,
#   < cv2.KeyPoint 0000024950637600>,
#   < cv2.KeyPoint 00000249506375D0>,
#   < cv2.KeyPoint 0000024950637420>,
#   < cv2.KeyPoint 0000024950637780>,
#   < cv2.KeyPoint 0000024950637300>,
#   < cv2.KeyPoint 00000249506376C0>,
#   < cv2.KeyPoint 0000024950637660>,
#   < cv2.KeyPoint 0000024950637690>,
#   < cv2.KeyPoint 0000024950636F70>,
#   < cv2.KeyPoint 00000249506376F0>,
#   < cv2.KeyPoint 0000024950637750>,
#   < cv2.KeyPoint 00000249506377B0>,
#   < cv2.KeyPoint 0000024950636A90>,
#   < cv2.KeyPoint 00000249506378A0>,
#   < cv2.KeyPoint 0000024950637960>,
#   < cv2.KeyPoint 00000249506378D0>,
#   < cv2.KeyPoint 0000024950637BA0>,
#   < cv2.KeyPoint 0000024950637930>,
#   < cv2.KeyPoint 0000024950637810>,
#   < cv2.KeyPoint 00000249506379C0>,
#   < cv2.KeyPoint 0000024950637CC0>,
#   < cv2.KeyPoint 0000024950637990>,
#   < cv2.KeyPoint 00000249506377E0>,
#   < cv2.KeyPoint 0000024950637BD0>,
#   < cv2.KeyPoint 0000024950637840>,
#   < cv2.KeyPoint 0000024950637C90>,
#   < cv2.KeyPoint 0000024950637870>,
#   < cv2.KeyPoint 0000024950636C10>,
#   < cv2.KeyPoint 0000024950637A50>,
#   < cv2.KeyPoint 0000024950637E40>,
#   < cv2.KeyPoint 0000024950637AB0>,
#   < cv2.KeyPoint 0000024950637AE0>,
#   < cv2.KeyPoint 0000024950637F00>,
#   < cv2.KeyPoint 0000024950637F60>,
#   < cv2.KeyPoint 0000024950637D20>,
#   < cv2.KeyPoint 0000024950637D80>,
#   < cv2.KeyPoint 0000024950637480>,
#   < cv2.KeyPoint 0000024950637F90>,
#   < cv2.KeyPoint 0000024950637FC0>,
#   < cv2.KeyPoint 0000024950637F30>,
#   < cv2.KeyPoint 00000249506372D0>,
#   < cv2.KeyPoint 0000024950637ED0>,
#   < cv2.KeyPoint 0000024950637C00>,
#   < cv2.KeyPoint 0000024950637A80>,
#   < cv2.KeyPoint 0000024950637C60>,
#   < cv2.KeyPoint 0000024950637A20>,
#   < cv2.KeyPoint 0000024950637DE0>,
#   < cv2.KeyPoint 0000024950637EA0>,
#   < cv2.KeyPoint 0000024950637D50>,
#   < cv2.KeyPoint 0000024950637900>,
#   < cv2.KeyPoint 0000024950648060>,
#   < cv2.KeyPoint 0000024950648030>,
#   < cv2.KeyPoint 0000024950648330>,
#   < cv2.KeyPoint 0000024950648240>,
#   < cv2.KeyPoint 0000024950648300>,
#   < cv2.KeyPoint 0000024950648180>,
#   < cv2.KeyPoint 00000249506481E0>,
#   < cv2.KeyPoint 0000024950648150>,
#   < cv2.KeyPoint 00000249506481B0>,
#   < cv2.KeyPoint 00000249506482A0>,
#   < cv2.KeyPoint 0000024950648120>,
#   < cv2.KeyPoint 0000024950648210>,
#   < cv2.KeyPoint 00000249506480F0>,
#   < cv2.KeyPoint 0000024950648780>,
#   < cv2.KeyPoint 0000024950648420>,
#   < cv2.KeyPoint 00000249506485D0>,
#   < cv2.KeyPoint 0000024950648390>,
#   < cv2.KeyPoint 0000024950648540>,
#   < cv2.KeyPoint 0000024950648600>,
#   < cv2.KeyPoint 0000024950648660>,
#   < cv2.KeyPoint 0000024950648450>,
#   < cv2.KeyPoint 0000024950648360>,
#   < cv2.KeyPoint 00000249506486F0>,
#   < cv2.KeyPoint 00000249506486C0>,
#   < cv2.KeyPoint 0000024950648720>,
#   < cv2.KeyPoint 00000249506484B0>,
#   < cv2.KeyPoint 0000024950648690>,
#   < cv2.KeyPoint 00000249506487B0>,
#   < cv2.KeyPoint 00000249506488D0>,
#   < cv2.KeyPoint 0000024950648810>),
#  array([[38.,  4.,  1., ...,  1.,  1.,  5.],
#         [ 8., 46.,  0., ...,  0.,  0.,  0.],
#         [20., 32., 35., ...,  0.,  1.,  2.],
#         ...,
#         [ 0.,  2., 17., ..., 53., 64., 70.],
#         [33., 31.,  3., ...,  0.,  0.,  0.],
#         [15., 73.,  3., ...,  0.,  0.,  0.]],
#        shape=(201, 128), dtype=float32))

# %% [markdown]
# second

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('simple.jpg', cv.IMREAD_GRAYSCALE)
# Initiate ORB detector
orb = cv.ORB_create()
# find the keypoints with ORB
kp = orb.detect(img,None)
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)
# draw only keypoints location,not size and orientation
img2 = cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x24952742060>, None)
